# %% [markdown]
# <a href="https://colab.research.google.com/github/rmontalvosalgado-ux/Programa_Civil_2026_1/blob/main/Dosificaci%C3%B3n_de_Mezcla_para_Columnas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dosificación de Mezcla para Columnas**
# **Planteamiento**:
#
# Un ingeniero residente necesita calcular cuántos sacos de cemento se requieren para vaciar una columna de sección circular.
#
# Se sabe que para un concreto estándar de 210 kg/cm2 (3000 psi), se consumen 9.5 sacos de cemento por cada metro cúbico de mezcla.
#
# **Requerimientos**:
#
# 1. Solicitar la altura de la columna en metros.
# 2. Solicitar el diámetro de la columna en metros.
# 3. Calcular el volumen de la columna: $$v = \pi * r ^2 * h$$
# . (Sugerencia: usar 3.1416
#  o importar math.pi).
# 4. Calcular la cantidad de sacos:
# $$sacos = v * 9.5$$
#
# **Prueba del programa**:
#
# Para una columna de 3 metros de alto y 0.4 metros de diámetro (r=0.2
# ):
#
# Volumen ≈0.377 m3.
#
# Sacos necesarios ≈3.58
#  (el estudiante verá aquí la importancia de los tipos decimales).

# %%
# ENTRADA: Solicitar la altura de la columna en metros.
# Solicitar el diámetro de la columna en metros.
h = float(input("Ingrese la altura de la columna en metros: "))
d = float(input("Ingrese el diámetro de la columna en metros: "))

# PROCESO: Calcula el radio r, calcula el volumen de la columna, calcula sacos
r = d/2
v = 3.1416 * r**2 * h
sacos = v * 9.5

# SALIDA: Imprimir el resultado
print("Volumen ≈", round(v, 3), "m3.")
print("Sacos necesarios ≈", round(sacos, 2))
# Out:
# Ingrese la altura de la columna en metros: 3
# Ingrese el diámetro de la columna en metros: 0.4
# Volumen ≈ 0.377 m3.
# Sacos necesarios ≈ 3.58

# %% [markdown]
# ```markdown
# # Explicación del código para el cálculo de sacos de cemento
#
# A continuación, se explica línea por línea el código proporcionado para el cálculo de sacos de cemento necesarios para una columna:
#
# ```python
# h = float(input("Ingrese la altura de la columna en metros: "))
# ```
# - **Explicación**: Esta línea solicita al usuario que ingrese la altura de la columna en metros. La función `input()` lee la entrada del usuario como una cadena de texto. Luego, `float()` convierte esa cadena a un número de punto flotante (decimal), lo que permite usar valores como `3.5` metros. El resultado se almacena en la variable `h`.
#
# ```python
# d = float(input("Ingrese el diámetro de la columna en metros: "))
# ```
# - **Explicación**: Similar a la línea anterior, esta línea solicita al usuario que ingrese el diámetro de la columna en metros. La entrada se convierte a un número de punto flotante y se guarda en la variable `d`.
#
# ```python
# r = d/2
# ```
# - **Explicación**: Calcula el radio de la columna. El radio (`r`) es la mitad del diámetro (`d`). El resultado se almacena en la variable `r`.
#
# ```python
# v = 3.1416 * r**2 * h
# ```
# - **Explicación**: Esta línea calcula el volumen (`v`) de la columna circular utilizando la fórmula $$v = \pi * r^2 * h$$. Se usa `3.1416` como una aproximación del valor de Pi (π). `r**2` calcula el radio al cuadrado. El resultado se guarda en la variable `v`.
#
# ```python
# sacos = v * 9.5
# ```
# - **Explicación**: Calcula la cantidad total de sacos de cemento necesarios. Se multiplica el volumen calculado (`v`) por la constante `9.5`, que representa la cantidad de sacos de cemento requeridos por cada metro cúbico de mezcla. El resultado se almacena en la variable `sacos`.
#
# ```python
# print("Volumen ≈", round(v, 3), "m3.")
# ```
# - **Explicación**: Imprime en la consola el volumen calculado de la columna. `round(v, 3)` redondea el valor del volumen a tres decimales para una mejor presentación. El texto "Volumen ≈" y "m3." se añaden para contextualizar el resultado.
#
# ```python
# print("Sacos necesarios ≈", round(sacos, 2))
# ```
# - **Explicación**: Imprime en la consola la cantidad de sacos de cemento necesarios. `round(sacos, 2)` redondea el número de sacos a dos decimales. El texto "Sacos necesarios ≈" se añade para contextualizar el resultado.
# ```
